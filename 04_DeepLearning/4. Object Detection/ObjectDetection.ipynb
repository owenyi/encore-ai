# %%
# !git clone https://github.com/eriklindernoren/PyTorch-YOLOv3
# Out:
# Cloning into 'PyTorch-YOLOv3'...
# remote: Enumerating objects: 1583, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 1583 (delta 17), reused 12 (delta 5), pack-reused 1544
# Receiving objects: 100% (1583/1583), 16.42 MiB | 41.92 MiB/s, done.
# Resolving deltas: 100% (944/944), done.

# %%
# %cd PyTorch-YOLOv3/
# Out:
# [Errno 2] No such file or directory: 'PyTorch-YOLOv3/'
# /content/PyTorch-YOLOv3/PyTorch-YOLOv3

# %%
# !pip3 install poetry # --user 빼야 됨

# %%
# !poetry install

# %%
# !bash ./weights/download_weights.sh
# Out:
# --2021-06-16 06:59:55--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  44.6MB/s    in 5.7s
#
# 2021-06-16 07:00:01 (41.8 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]
#
# --2021-06-16 07:00:01--  https://pjreddie.com/media/files/yolov3-tiny.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35434956 (34M) [application/octet-stream]
# Saving to: ‘yolov3-tiny.weights’
#
# yolov3-tiny.weights 100%[===================>]  33.79M  30.3MB/s    in 1.1s
#
# ...

# %%
# !pip uninstall imgaug && pip uninstall albumentations && pip install git+https://github.com/aleju/imgaug.git

# %%
# !pip3 install pytorchyolo

# %%
# !poetry shell # poetry 쉘에 pip install ipykernel 넣기
# Out:
# Spawning shell within /root/.cache/pypoetry/virtualenvs/pytorchyolo-9v2T40J2-py3.7
# 2-py3.7/bin/activate
# (pytorchyolo-9v2T40J2-py3.7) /content/PyTorch-YOLOv3# ^C

# %%
# !poetry run yolo-detect --images data/samples/ # yolov3.wegihts 파일 잘 넣어줘야 함
# Out:
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/usr/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 967, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 677, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/content/PyTorch-YOLOv3/pytorchyolo/detect.py", line 23, in <module>
#     import matplotlib.pyplot as plt
#   File "/root/.cache/pypoetry/virtualenvs/pytorchyolo-9v2T40J2-py3.7/lib/python3.7/site-packages/matplotlib/pyplot.py", line 2336, in <module>
#     switch_backend(rcParams["backend"])
# ...
